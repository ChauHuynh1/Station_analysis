# %% [markdown]
# <h1 style="color:#1E7FC1;font-size:50px;font-family:Georgia;text-align:center;"><strong>EEET2485 - Research Methods for Engineers</strong></h1>
# <h1 style="color:#4594C8;font-size:50px;font-family:Georgia;text-align:center;"><strong>Group Assignment</strong></h1>
# <h2 style="color:#4594C8;font-size:50px;font-family:Georgia;text-align:center;"><strong>E-Scooter Stations Analysis</strong></h2>
#
# ## <b style='color:#1E7FC1;'>Students:</b>
# ### <b>Tran Khai Minh (s3818343)</b>
# ### <b>Nguyen Huy Hoang (s3764704)</b>
# ### <b>Nguyen Nhat Tan (s3818559)</b>
# ### <b>Tong Son Tung (s3818153)</b>
# ### <b>Nguyen Thanh Loan (s3821185)</b>
#
# ## <b style='color:#1E7FC1;'>Group Number:</b> <b>2</b>
#
# ## <b style='color:#1E7FC1;'>Assigned Dataset:</b> <b>2</b>
#
# ## <b style='color:#1E7FC1;'>Lecturer:</b> <b>Dr. Arthur Tang</b>
#
# ## <b style='color:#1E7FC1;'>Due Date:</b> <b>January 13, 2023</b>

# %% [markdown]
# <h1 style="color:#00008B;font-size:40px;font-family:Georgia;text-align:center;"><strong>Table of Content</strong></h1>
#
# ### [I. Data Preparation](#1)
#
# > [1.1. Introduction](#1.1.)
#
# > [1.2. Research Questions](#1.2.)
#
# > [1.3. Importing neccessary libraries](#1.3.)
#
# > [1.4. Importing the dataset](#1.4.)
#
# > [1.5. Data information](#1.5.)
#
# <br>
#
# ### [II. Data Cleaning and Pre-processing](#2)
#
# > [2.1. Drop duplicate(s)](#2.1.)
#
# > [2.2. Outliers(s)](#2.2.)
#
# <br>
#
# ### [III. Data Analysis](#3)
#
# >  [3.1. RQ1: Which weather factor(s) most likely affect the number of e-scooter rentees?](#3.1.)
#
# >  [3.2. RQ2: Is there a relationship between Temperature and Dew Point Temperature?](#3.2.)
#
# >  [3.3. RQ3: Which season are people most/least likely to rent an e-scooter?](#3.3.)
#
# >  [3.4. RQ4: Which station has the most/least e-scooter rent in a given day?](#3.4.)
#
# >  [3.5. RQ5: Is season a factor for e-scooter stations’ closure?](#3.5.)
# >  [3.6. RQ6: Are people more likely to rent an e-scooter when the temperature is above 20°C?](#3.6.)
#
# >  [3.7. RQ7: Are people more likely to rent an e-scooter on completely dry (no rain, no snow) days?](#3.7.)
#
# >  [3.8. RQ8: Has the percentage of registered/newly registered user increased after 6 months (from Dec 2017 to Jun 2018)?](#3.8.)
#
# >  [3.9. RQ9: Are stations attracting unregistered users to register?](#3.9.)
#
# <br>
#
# ### [IV. References](#4)
#
# <hr>

# %% [markdown]
# <a id="1"></a>
# <h1 style="color:#00008B;font-size:40px;font-family:Georgia;text-align:center;"><strong>I. Data Preparation</strong></h1>

# %% [markdown]
# <a id="1.1."></a>
# # 1.1. Introduction
# ****
# The dataset is a record from 24 e-scooter rental stations from Winter 2017 to Autumn 2018. Each entry in the record includes the number of users from different classes, together with the weather features on that day. The analysis of this dataset will give insights into e-scooter rentees' behavior as well as the factors affecting the operation of the e-scooter stations.

# %% [markdown]
# <a id="1.2."></a>
# # ️1.2. Research Questions (RQs)
# ****
# > - ***RQ1:*** Which weather factor(s) most likely affect the number of e-scooter rentees?
#
# > - ***RQ2:*** Is there a relationship between temperature and dew point temperature?
#
# > - ***RQ3:*** Which season are people most/least likely to rent an e-scooter?
#
# > - ***RQ4:*** Which station has the most/least e-scooter rent in a single day?
#
# > - ***RQ5:*** Is season a factor for e-scooter station's closure?
#
# > - ***RQ6:*** Are people more likely to rent an e-scooter when the temperature is above 20°C?
#
# > - ***RQ7:*** Are people more likely to rent an e-scooter on completely dry days (no rain, no snow)?
#
# > - ***RQ8:*** Has the percentage of registered/newly registered user increase after 6 months (from Dec 2017 to Jun 2018)?
#
# > - ***RQ9:*** Do unregistered rentees prefer to register or stay casual?

# %% [markdown]
# <a id="1.3."></a>
# # 1.3. Importing neccessary libraries
# ****

# %%
# Turning off warninng
from IPython.display import HTML
HTML('''<script>
code_show_err=false; 
function code_toggle_err() {
 if (code_show_err){
 $('div.output_stderr').hide();
 } else {
 $('div.output_stderr').show();
 }
 code_show_err = !code_show_err
} 
$( document ).ready(code_toggle_err);
</script>
To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.''')
# Out:
# <script>
# code_show_err=false;
# function code_toggle_err() {
#  if (code_show_err){
#  $('div.output_stderr').hide();
#  } else {
#  $('div.output_stderr').show();
#  }
#  code_show_err = !code_show_err
# }
# $( document ).ready(code_toggle_err);
# </script>
# To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.

# %%
# !pip -q install pingouin

# Import pandas and numpy libraries
import pandas as pd
import numpy as np

# Scipy stats library for statistical tests (Pearson R, t-test, ANOVA, chi-square, Levene's,...)
import scipy
import scipy.stats as stats

# Library for Welch's ANOVA and Games-Howell post-hoc tests
import pingouin as pg

# Libraries for plotting
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# Set default figure size
plt.rcParams["figure.figsize"]= 5, 5
# Setting theme in seaborn
sns.set_theme(style="ticks", color_codes=True) 

import warnings
warnings.filterwarnings('ignore') # Ignore warnings

# %% [markdown]
# ## Checking software version

# %%
# Check the version of the packages
! python --version
print("Numpy version: ", np.__version__)
print("Pandas version: ",pd.__version__)
print("Scipy version: ", scipy.__version__)
# Out:
# Python 3.9.13
# Numpy version:  1.21.5
# Pandas version:  1.4.4
# Scipy version:  1.9.1

# %% [markdown]
# <a id="1.4."></a>
# # 1.4. Importing the dataset
# ***

# %%
df = pd.read_excel("dataset2.xlsx")

df.columns = df.columns.str.replace(' ', '') # Strip whitespaces

print("The shape of the ORIGINAL data is (row, column):", str(df.shape))

df.head()
# Out:
# The shape of the ORIGINAL data is (row, column): (8760, 23)
#    StationNumber                 Date  CasualUser  RegisteredUser  \
# 0              1  2017-01-12 00:00:00        80.0             254
# 1              2  2017-01-12 00:00:00        79.0             204
# 2              3  2017-01-12 00:00:00        81.0             173
# 3              4  2017-01-12 00:00:00        48.0             107
# 4              5  2017-01-12 00:00:00        30.0              78
#
#    Newregistereduser  Temperature(°C)  Humidity(%)  Windspeed(m/s)  \
# 0                  5             -5.2           37             2.2
# 1                  6             -5.5           38             0.8
# 2                  8             -6.0           39             1.0
# 3                  3             -6.2           40             0.9
# 4                  3             -6.0           36             2.3
#
#    Visibility(10m)  Dewpointtemperature(°C)  ...  Seasons  OperationDay  \
# 0             2000                    -17.6  ...   Winter           Yes
# 1             2000                    -17.6  ...   Winter           Yes
# 2             2000                    -17.7  ...   Winter           Yes
# 3             2000                    -17.6  ...   Winter           Yes
# 4             2000                    -18.6  ...   Winter           Yes
#
#    TotalUser CasualPercent RegisteredPercent  NewRegisteredPercent  \
# 0      339.0     23.598820         74.926254              1.474926
# 1      289.0     27.335640         70.588235              2.076125
# 2      262.0     30.916031         66.030534              3.053435
# 3      158.0     30.379747         67.721519              1.898734
# 4      111.0     27.027027         70.270270              2.702703
#
#    CompletelyDry  Below20  IsDec2017 IsJun2018
# 0            Yes      Yes        Yes        No
# 1            Yes      Yes        Yes        No
# 2            Yes      Yes        Yes        No
# 3            Yes      Yes        Yes        No
# 4            Yes      Yes        Yes        No
#
# [5 rows x 23 columns]

# %% [markdown]
# <a id="1.5."></a>
# # 1.5. Data Information
# ****
# Get the general information about the dataset.

# %%
print ("The shape of the dataset is (row, column):"+ str(df.shape))
df.info()
# Out:
# The shape of the dataset is (row, column):(8760, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   StationNumber            8760 non-null   int64
#  1   Date                     8760 non-null   object
#  2   CasualUser               8760 non-null   float64
#  3   RegisteredUser           8760 non-null   int64
#  4   Newregistereduser        8760 non-null   int64
#  5   Temperature(°C)          8760 non-null   float64
#  6   Humidity(%)              8760 non-null   int64
#  7   Windspeed(m/s)           8760 non-null   float64
#  8   Visibility(10m)          8760 non-null   int64
#  9   Dewpointtemperature(°C)  8760 non-null   float64
#  10  SolarRadiation(MJ/m2)    8760 non-null   float64
#  11  Rainfall(mm)             8760 non-null   float64
#  12  Snowfall(cm)             8760 non-null   float64
#  13  Seasons                  8760 non-null   object
#  14  OperationDay             8760 non-null   object
#  15  TotalUser                8760 non-null   float64
#  16  CasualPercent            8760 non-null   float64
#  17  RegisteredPercent        8760 non-null   float64
#  18  NewRegisteredPercent     8760 non-null   float64
#  19  CompletelyDry            8760 non-null   object
#  20  Below20                  8760 non-null   object
#  21  IsDec2017                8760 non-null   object
#  22  IsJun2018                8760 non-null   object
# dtypes: float64(11), int64(5), object(7)
# memory usage: 1.5+ MB

# %% [markdown]
# The dataset has a total of 23 columns (15 original + 8 added in Excel file) and 8760 rows with no missing value.
# ***
# The original 15 columns of the dataset are of type:
# ***
# **Categorical:**
# - **Nominal** (variables that have two or more categories, but which do not have an intrinsic order.)
#  > - **Station Number:** The number of the station to which the record belongs (Station 1 - 24).
#  > - **Date:** The date when the data was recorded.
#  > - **Seasons:** The current season on the day of the record.
#  > - **OperationDay:** Whether the station is open on the day of the record.
#
# ***
# **Numeric:**
# - **Continuous**
#  > - **Casual User:** The number of casual (non-registered) users on the day of the record.
#  > - **Registered User:** The number of registered users on the day of the record.
#  > - **New registered user:** The number of users who registered right on the day of the record.
#  > - **Temperature (°C):** Average temperature at the station on the day of the record.
#  > - **Humidity (%):** Average humidity at the station on the day of the record.
#  > - **Windspeed (m/s):** Average wind speed at the station on the day of the record.
#  > - **Visibility (10m):** Average visibility at the station on the day of the record.
#  > - **Dew point temperature (°C):** Average dew point temperature at the station on the day of the record.
#  > - **SolarRadiation (MJ/m2):** Average solar radiation at the station on the day of the record.
#  > - **Rainfall (mm):** Average rainfall rate at the station on the day of the record.
#  > - **Snowfall (cm):** Average snowfall rate at the station on the day of the record.
# ***
#
# Additionally, there are 8 columns that are added based on the original data to aid with the analysis:
# ***
#
# **Categorical:**
# - **Nominal** (variables that have two or more categories, but which do not have an intrinsic order.)
#  >  - **CompletelyDry:** Whether day of the record has no rain and snow.
#  >  - **Below20:** Whether the average temperature were below 20°C on the day of the record.
#  >  - **IsDec2017:** Whether the record was logged on December 2017.
#  >  - **IsJun2018:** Whether the record was logged on June 2018.
# ***
# **Numeric:**
# - **Continuous**
#  >  - **TotalUser:** Total number of users on the day of the record, including non-registered and registered.
#  >  - **CasualPercent (%):** Percentage of casual users on the day of the record.
#  >  - **RegisteredPercent (%):** Percentage of registered users on the day of the record.
#  >  - **NewRegisteredPercent (%):** Percentage of newly registered users on the day of the record.

# %% [markdown]
# <a id="2"></a>
# <h1 style="color:#00008B;font-size:40px;font-family:Georgia;text-align:center;"><strong>II. Data Cleaning and Pre-processing</strong></h1>

# %% [markdown]
# <a id="2.1."></a>
# # 2.1. Drop duplicate
# ***

# %%
print ("The shape of the dataset before dropping duplicate entries:"+ str(df.shape))

df = df.drop_duplicates()

print ("The shape of the dataset after dropping duplicate entries:"+ str(df.shape))
# Out:
# The shape of the dataset before dropping duplicate entries:(8760, 23)
# The shape of the dataset after dropping duplicate entries:(8760, 23)

# %% [markdown]
# ### Discussion:
# ***
# There is no duplicate entry in this dataset.

# %% [markdown]
# <a id="2.2."></a>
# # 2.2. Outliers
# ****
# ## Detection Method
# Outliers are indentified using the interquartile range (IQR) rule:
# Any value fall outside of the Q1 - 1.5 x IQR - Q3 + 1.5 x IQR is considered as outlier.
# Q1 and Q3 are the first and third quartiles of the data, respectively.
# The IQR measures how the data is spread about the median. Therefore it is useful in detecting outliers.
# *****

# %% [markdown]
# ## Descriptive Statistics

# %%
# Descriptive statistics of all numerical fields
df.describe().T
# Out:
#                           count         mean         std   min         25%  \
# StationNumber            8760.0    12.500000    6.922582   1.0    6.750000
# CasualUser               8760.0   279.777523  266.546813   0.0   69.000000
# RegisteredUser           8760.0   704.602055  644.997468   0.0  191.000000
# Newregistereduser        8760.0    22.454566   22.155487   0.0    5.000000
# Temperature(°C)          8760.0    12.993653   12.271382 -17.8    3.500000
# Humidity(%)              8760.0    58.226256   20.362413   0.0   42.000000
# Windspeed(m/s)           8760.0     1.724909    1.036300   0.0    0.900000
# Visibility(10m)          8760.0  1436.825799  608.298712  27.0  940.000000
# Dewpointtemperature(°C)  8760.0     4.073813   13.060369 -30.6   -4.700000
# SolarRadiation(MJ/m2)    8760.0     0.569111    0.868746   0.0    0.000000
# Rainfall(mm)             8760.0     0.148687    1.128193   0.0    0.000000
# Snowfall(cm)             8760.0     0.075068    0.436746   0.0    0.000000
# TotalUser                8760.0  1006.834144  930.154714   1.0  267.000000
# CasualPercent            8760.0    29.139219   13.772225   0.0   25.026670
# RegisteredPercent        8760.0    68.838421   13.498710   0.0   68.213764
# NewRegisteredPercent     8760.0     2.022360    0.955831   0.0    1.764608
#
#                                  50%          75%         max
# StationNumber              12.500000    18.250000    24.00000
# CasualUser                195.000000   424.000000  1599.00000
# RegisteredUser            504.500000  1065.250000  3556.00000
# Newregistereduser          15.000000    34.000000   159.00000
# Temperature(°C)            13.800000    22.600000   124.00000
# Humidity(%)                57.000000    74.000000    98.00000
# Windspeed(m/s)              1.500000     2.300000     7.40000
# Visibility(10m)          1698.000000  2000.000000  2000.00000
# Dewpointtemperature(°C)     5.100000    14.800000    27.20000
# SolarRadiation(MJ/m2)       0.010000     0.930000     3.52000
# Rainfall(mm)                0.000000     0.000000    35.00000
# Snowfall(cm)                0.000000     0.000000     8.80000
# TotalUser                 715.500000  1522.250000  5193.00000
# CasualPercent              27.066892    29.480517   100.00000
# RegisteredPercent          70.805825    73.015873   100.00000
# NewRegisteredPercent        2.066116     2.400000    31.33515

# %%
# Box plot for all numerical fields
sns.boxplot(data=df[['CasualUser', 
                     'RegisteredUser', 
                     'Newregistereduser', 
                     'Temperature(°C)', 
                     'Humidity(%)', 
                     'Windspeed(m/s)',
                     'Visibility(10m)',
                     'Dewpointtemperature(°C)',
                     'SolarRadiation(MJ/m2)',
                     'Rainfall(mm)',
                     'Snowfall(cm)']], 
            orient="h")

plt.title('Box plots of numerical fields')
# Out:
# Text(0.5, 1.0, 'Box plots of numerical fields')

# %%
# Zoomed in for easier observation
fig, ax = plt.subplots(4, 1, figsize=(10, 20));
meanlineprops = dict(linestyle='-.', linewidth=2.5, color='white')

sns.boxplot(data=df[['CasualUser', 
                     'RegisteredUser', 
                     'Newregistereduser',
                     'Visibility(10m)']], 
            orient='h',
            showmeans=True,
            meanline=True,
            meanprops=meanlineprops,
            ax=ax[0])

sns.boxplot(data=df[['Temperature(°C)', 
                     'Humidity(%)', 
                     'Dewpointtemperature(°C)']], 
            orient='h',
            showmeans=True,
            meanline=True,
            meanprops=meanlineprops,
            ax=ax[1])

sns.boxplot(data=df[['Windspeed(m/s)',
                     'SolarRadiation(MJ/m2)']], 
            orient='h',
            showmeans=True,
            meanline=True,
            meanprops=meanlineprops,
            ax=ax[2])

sns.boxplot(data=df[['Rainfall(mm)', 'Snowfall(cm)']], 
            orient='h',
            showmeans=True,
            meanline=True,
            meanprops=meanlineprops,
            ax=ax[3])
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are outliers in `CasualUser`, `RegisteredUser`, `Newregisteruser`, `Temperature`, `Windspeed`, and `SolarRadiation` columns.
# > The outliers in `Temperature` is of the most concern, since the values of the outliers are unrealisticly higher than the highest temperature that was ever recorded in the world. [[1]](#Ref1)
#
# > The outliers in `SolarRadiation` are packed very close together, they might indicate a special condition.
#
# > A lot of `Rainfall` and `Snowfall` values are 0, therefore any value that is not 0 are probably identified as outliers, even though they are not neccessarily outliers. These data will be grouped into days without rain or no snow (rain & snow equal 0) and days with rain or snow (rain & snow not equal 0).

# %% [markdown]
# ## Detecting and Dealing with outliers

# %%
def detect_outliers_IQR(df):
   # Find Q1:
   Q1 = np.percentile(df, 25)
   # Find Q3:
   Q3 = np.percentile(df, 75)
   # Find the IQR:
   IQR = Q3 - Q1
   # Upper bound
   upper_lim = Q3 + 1.5*IQR
   # Lower bound
   lower_lim = Q1 - 1.5*IQR
   # Outliers
   outliers = df[((df < (Q1 - 1.5*IQR)) | (df > (Q3 + 1.5*IQR)))]
   return outliers, upper_lim, lower_lim

# %% [markdown]
# ### **`CasualUser` outliers**

# %%
df.boxplot(column= "CasualUser")
# Out:
# <AxesSubplot:>

# %%
outliers, upper_lim, lower_lim = detect_outliers_IQR(df['CasualUser'])

print("number of outliers: "+ str(len(outliers)))

print("max outlier value: "+ str(outliers.max()))

print("min outlier value: "+ str(outliers.min()))

print("percentage of outliers: "+ str(len(outliers)/len(df) * 100))
# Out:
# number of outliers: 200
# max outlier value: 1599.0
# min outlier value: 958.0
# percentage of outliers: 2.28310502283105

# %%
df[(df['CasualUser'] < lower_lim) | (df['CasualUser'] > upper_lim)].head()
# Out:
#       StationNumber                 Date  CasualUser  RegisteredUser  \
# 3114             19  2018-09-04 00:00:00      1108.0            2401
# 3186             19  2018-12-04 00:00:00       987.0            2359
# 3210             19           13/04/2018      1093.0            2404
# 3474             19           24/04/2018      1002.0            2318
# 3498             19           25/04/2018      1260.0            2807
#
#       Newregistereduser  Temperature(°C)  Humidity(%)  Windspeed(m/s)  \
# 3114                110             14.8           24             1.3
# 3186                 70             17.9           16             3.7
# 3210                 91             17.5           18             1.3
# 3474                 91             14.1           43             1.6
# 3498                105             21.2           32             3.8
#
#       Visibility(10m)  Dewpointtemperature(°C)  ...  Seasons  OperationDay  \
# 3114             1514                     -5.6  ...   Spring           Yes
# 3186             2000                     -8.3  ...   Spring           Yes
# 3210             2000                     -7.1  ...   Spring           Yes
# 3474             2000                      1.6  ...   Spring           Yes
# 3498             1927                      3.8  ...   Spring           Yes
#
#       TotalUser CasualPercent RegisteredPercent  NewRegisteredPercent  \
# 3114     3619.0     30.616192         66.344294              3.039514
# 3186     3416.0     28.893443         69.057377              2.049180
# 3210     3588.0     30.462653         67.001115              2.536232
# 3474     3411.0     29.375550         67.956611              2.667839
# 3498     4172.0     30.201342         67.281879              2.516779
#
#       CompletelyDry  Below20  IsDec2017 IsJun2018
# 3114            Yes      Yes         No        No
# 3186            Yes      Yes         No        No
# 3210            Yes      Yes         No        No
# 3474            Yes      Yes         No        No
# 3498            Yes       No         No        No
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Discussion:
# ****
# A quick look at the outliers shows that the number of `CasualUser` is especially high with certain weather condition. There might be a correlation. Therefore, all the outliers in the `CasualUser` is kept for further analysis.

# %% [markdown]
# ### `RegisteredUser` outliers

# %%
df.boxplot(column= "RegisteredUser")
# Out:
# <AxesSubplot:>

# %%
outliers, upper_lim, lower_lim = detect_outliers_IQR(df['RegisteredUser'])

print("number of outliers: "+ str(len(outliers)))

print("max outlier value: "+ str(outliers.max()))

print("min outlier value: "+ str(outliers.min()))

print("percentage of outliers: "+ str(len(outliers)/len(df) * 100))
# Out:
# number of outliers: 158
# max outlier value: 3556
# min outlier value: 2377
# percentage of outliers: 1.8036529680365299

# %%
df[(df['RegisteredUser'] < lower_lim) | (df['RegisteredUser'] > upper_lim)].head()
# Out:
#       StationNumber                 Date  CasualUser  RegisteredUser  \
# 2946             19  2018-02-04 00:00:00       919.0            2401
# 2994             19  2018-04-04 00:00:00       951.0            2402
# 3114             19  2018-09-04 00:00:00      1108.0            2401
# 3210             19           13/04/2018      1093.0            2404
# 3282             19           16/04/2018       929.0            2692
#
#       Newregistereduser  Temperature(°C)  Humidity(%)  Windspeed(m/s)  \
# 2946                 76             20.7           54             4.1
# 2994                 86             16.0           47             2.1
# 3114                110             14.8           24             1.3
# 3210                 91             17.5           18             1.3
# 3282                 71             17.0           28             3.1
#
#       Visibility(10m)  Dewpointtemperature(°C)  ...  Seasons  OperationDay  \
# 2946             1484                     11.0  ...   Spring           Yes
# 2994             2000                      4.6  ...   Spring           Yes
# 3114             1514                     -5.6  ...   Spring           Yes
# 3210             2000                     -7.1  ...   Spring           Yes
# 3282             2000                     -1.6  ...   Spring           Yes
#
#       TotalUser CasualPercent RegisteredPercent  NewRegisteredPercent  \
# 2946     3396.0     27.061249         70.700824              2.237927
# 2994     3439.0     27.653388         69.845885              2.500727
# 3114     3619.0     30.616192         66.344294              3.039514
# 3210     3588.0     30.462653         67.001115              2.536232
# 3282     3692.0     25.162514         72.914410              1.923077
#
#       CompletelyDry  Below20  IsDec2017 IsJun2018
# 2946            Yes       No         No        No
# 2994            Yes      Yes         No        No
# 3114            Yes      Yes         No        No
# 3210            Yes      Yes         No        No
# 3282            Yes      Yes         No        No
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Discussion:
# ****
# A quick look at the outliers shows that the number of `RegisteredUser` is especially high with certain weather condition. There might be a correlation. Therefore, all the outliers in the `RegisteredUser` is kept for further analysis.

# %% [markdown]
# ### `Newregistereduser` outliers

# %%
df.boxplot(column= "Newregistereduser")
# Out:
# <AxesSubplot:>

# %%
outliers, upper_lim, lower_lim = detect_outliers_IQR(df['Newregistereduser'])

print("number of outliers: "+ str(len(outliers)))

print("max outlier value: "+ str(outliers.max()))

print("min outlier value: "+ str(outliers.min()))

print("percentage of outliers: "+ str(len(outliers)/len(df) * 100))
# Out:
# number of outliers: 256
# max outlier value: 159
# min outlier value: 78
# percentage of outliers: 2.922374429223744

# %%
df[(df['Newregistereduser'] < lower_lim) | (df['Newregistereduser'] > upper_lim)].head()
# Out:
#       StationNumber                 Date  CasualUser  RegisteredUser  \
# 2490             19           14/03/2018       869.0            2100
# 2994             19  2018-04-04 00:00:00       951.0            2402
# 3114             19  2018-09-04 00:00:00      1108.0            2401
# 3210             19           13/04/2018      1093.0            2404
# 3354             19           19/04/2018       924.0            2198
#
#       Newregistereduser  Temperature(°C)  Humidity(%)  Windspeed(m/s)  \
# 2490                 86             19.2           53             2.4
# 2994                 86             16.0           47             2.1
# 3114                110             14.8           24             1.3
# 3210                 91             17.5           18             1.3
# 3354                 84             19.1           31             3.0
#
#       Visibility(10m)  Dewpointtemperature(°C)  ...  Seasons  OperationDay  \
# 2490             2000                      9.3  ...   Spring           Yes
# 2994             2000                      4.6  ...   Spring           Yes
# 3114             1514                     -5.6  ...   Spring           Yes
# 3210             2000                     -7.1  ...   Spring           Yes
# 3354              958                      1.5  ...   Spring           Yes
#
#       TotalUser CasualPercent RegisteredPercent  NewRegisteredPercent  \
# 2490     3055.0     28.445172         68.739771              2.815057
# 2994     3439.0     27.653388         69.845885              2.500727
# 3114     3619.0     30.616192         66.344294              3.039514
# 3210     3588.0     30.462653         67.001115              2.536232
# 3354     3206.0     28.820961         68.558952              2.620087
#
#       CompletelyDry  Below20  IsDec2017 IsJun2018
# 2490            Yes      Yes         No        No
# 2994            Yes      Yes         No        No
# 3114            Yes      Yes         No        No
# 3210            Yes      Yes         No        No
# 3354            Yes      Yes         No        No
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Discussion:
# ****
# A quick look at the outliers shows that the number of `RegisteredUser` is especially high with certain weather condition. There might be a correlation. Therefore, all the outliers in the `RegisteredUser` is kept for further analysis.

# %% [markdown]
# ### `Temperature(°C)` outliers

# %%
df.boxplot(column="Temperature(°C)")
plt.title('Temperature(°C) before replacing outliers with median')
# Out:
# Text(0.5, 1.0, 'Temperature(°C) before replacing outliers with median')

# %%
outliers, upper_lim, lower_lim = detect_outliers_IQR(df['Temperature(°C)'])

print("number of outliers: "+ str(len(outliers)))

print("max outlier value: "+ str(outliers.max()))

print("min outlier value: "+ str(outliers.min()))

print("percentage of outliers: "+ str(len(outliers)/len(df) * 100))
# Out:
# number of outliers: 10
# max outlier value: 124.0
# min outlier value: 77.0
# percentage of outliers: 0.1141552511415525

# %% [markdown]
# ### Discussion:
# ****
# The percentage of outliers in `Temperature(°C)` is extremely small so all entries with outliers are replaced with the median value.

# %%
median_temp = df['Temperature(°C)'].median()
df['Temperature(°C)'] = np.where((df['Temperature(°C)'] < lower_lim) | (df['Temperature(°C)'] > upper_lim), 
                                 median_temp,
                                 df['Temperature(°C)'])
        
df.boxplot(column="Temperature(°C)")
plt.title('Temperature(°C) after replacing outliers with median')
# Out:
# Text(0.5, 1.0, 'Temperature(°C) after replacing outliers with median')

# %% [markdown]
# ### `Windspeed` outliers

# %%
df.boxplot(column= "Windspeed(m/s)")
plt.title('Windspeed(m/s) before replacing outliers with median')
# Out:
# Text(0.5, 1.0, 'Windspeed(m/s) before replacing outliers with median')

# %%
outliers, upper_lim, lower_lim = detect_outliers_IQR(df['Windspeed(m/s)'])

print("number of outliers: "+ str(len(outliers)))

print("max outlier value: "+ str(outliers.max()))

print("min outlier value: "+ str(outliers.min()))

print("percentage of outliers: "+ str(len(outliers)/len(df) * 100))
# Out:
# number of outliers: 161
# max outlier value: 7.4
# min outlier value: 4.4
# percentage of outliers: 1.8378995433789953

# %% [markdown]
# ### Discussion:
# ****
# The percentage of outliers in `Windspeed(m/s)` is extremely small so all entries with outliers are replaced with the median value.

# %%
median_windspeed = df['Windspeed(m/s)'].median()
df['Windspeed(m/s)'] = np.where((df['Windspeed(m/s)'] < lower_lim) | (df['Windspeed(m/s)'] > upper_lim), 
                                 median_windspeed,
                                 df['Windspeed(m/s)'])
        
df.boxplot(column="Windspeed(m/s)")
plt.title('Windspeed(m/s) after replacing outliers with median')
# Out:
# Text(0.5, 1.0, 'Windspeed(m/s) after replacing outliers with median')

# %% [markdown]
# <a id="3"></a>
# <h1 style="color:#00008B;font-size:40px;font-family:Georgia;text-align:center;"><strong>III. Data Analysis </strong></h1>
#
# ****

# %% [markdown]
# <a id="3.1."></a>
# ### 3.1. RQ1. Which weather factor(s) most likely affect the number of e-scooter rentees?
# ****

# %% [markdown]
# ### Correlation between `Temperature` and `TotalUser`:
# *****
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : `Temperature` and `TotalUser` are not correlated.
# > * **Alternative hypothesis ($H_1$)**: `Temperature` and `TotalUser`  are correlated.
#
# **Significance level:** 0.05

# %%
sns.scatterplot(x="Temperature(°C)", y="TotalUser", data=df);

# %%
stats.pearsonr(df['TotalUser'], df['Temperature(°C)'])
# Out:
# PearsonRResult(statistic=0.5390399360461402, pvalue=0.0)

# %% [markdown]
# ### Discussion:
# ****
# `Temperature` and `TotalUser` have a strong positive correlation because:
# > - p-value is lower than the ***significance level (0.05)***, therfore ***$H_0$ is REJECTED***.
# > - The Pearson correlation coefficient (r) is high: 0.539.

# %% [markdown]
# ### Correlation between `Humidity` and `TotalUser`:
# *****
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : `Humidity` and `TotalUser` are not correlated.
# > * **Alternative hypothesis ($H_1$)**: `Humidity` and `TotalUser` are correlated.
#
# **Significance level:** 0.05

# %%
sns.scatterplot(x="Humidity(%)", y="TotalUser", data=df);

# %%
stats.pearsonr(df['TotalUser'], df['Humidity(%)'])
# Out:
# PearsonRResult(statistic=-0.19810683803056534, pvalue=3.09612050171823e-78)

# %% [markdown]
# ### Discussion:
# ****
# `Humidity` and `TotalUser` have a weak negative correlation because:
# > - p-value is lower than the ***significance level (0.05)***, therefore ***$H_0$ is REJECTED***.
# > - The Pearson correlation coefficient (r) is low: -0.198.

# %% [markdown]
# ### Correlation between `Windspeed` and `TotalUser`:
# *****
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : `Windspeed` and `TotalUser` are not correlated.
# > * **Alternative hypothesis ($H_1$)**: `Windspeed` and `TotalUser` are correlated.
#
# **Significance level:** 0.05

# %%
sns.scatterplot(x="Windspeed(m/s)", y="TotalUser", data=df);

# %%
stats.pearsonr(df['TotalUser'], df['Windspeed(m/s)'])
# Out:
# PearsonRResult(statistic=0.1502928789776857, pvalue=2.003863654479908e-45)

# %% [markdown]
# ### Discussion:
# ****
# `Windspeed` and `CasualUser` have a weak positive correlation because:
# > - p-value is lower than the ***significance level (0.05)***, therefore ***$H_0$ is REJECTED***.
# > - The Pearson correlation coefficient (r) is low: 0.150.

# %% [markdown]
# ### Correlation between `Visibility` and `TotalUser`:
# *****
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : `Visibility` and `TotalUser` are not correlated.
# > * **Alternative hypothesis ($H_1$)**: `Visibility` and `TotalUser` are correlated.
#
# **Significance level:** 0.05

# %%
sns.scatterplot(x="Visibility(10m)", y="TotalUser", data=df);

# %%
stats.pearsonr(df['TotalUser'], df['Visibility(10m)'])
# Out:
# PearsonRResult(statistic=0.19704492083045477, pvalue=2.10657103474783e-77)

# %% [markdown]
# ### Discussion:
# ****
# `Visibility` and `CasualUser` have a weak positive correlation because:
# > - p-value is lower than the ***significance level (0.05)***, therefore ***$H_0$ is REJECTED***.
# > - The Pearson correlation coefficient (r) is low: 0.197.

# %% [markdown]
# ### Correlation between `Dewpointtemperature` and `TotalUser`:
# *****
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : `DewPointTemperature` and `TotalUser` are not correlated.
# > * **Alternative hypothesis ($H_1$)**: `DewPointTemperature` and `TotalUser` are correlated.
#
# **Significance level:** 0.05

# %%
sns.scatterplot(x="Dewpointtemperature(°C)", y="TotalUser", data=df);

# %%
stats.pearsonr(df['TotalUser'], df['Dewpointtemperature(°C)'])
# Out:
# PearsonRResult(statistic=0.38129218880794424, pvalue=3.758925466239121e-301)

# %% [markdown]
# ### Discussion:
# ****
# `Dewpointtemperature` and `TotalUser` have a moderate positive correlation because:
# > - p-value is lower than the ***significance level (0.05)***, therefore ***$H_0$ is REJECTED***.
# > - The Pearson correlation coefficient (r) is medium: 0.381.

# %% [markdown]
# ### Correlation between `SolarRadiation` and `TotalUser`:
# *****
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : `SolarRadiation` and `TotalUser` are not correlated.
# > * **Alternative hypothesis ($H_1$)**: `SolarRadiation`and `TotalUser` are correlated.
#
# **Significance level:** 0.05

# %%
sns.scatterplot(x="SolarRadiation(MJ/m2)", y="TotalUser", data=df);

# %%
stats.pearsonr(df['TotalUser'], df['SolarRadiation(MJ/m2)'])
# Out:
# PearsonRResult(statistic=0.26174751609973007, pvalue=3.4665510703200177e-137)

# %% [markdown]
# ### Discussion:
# ****
# `SolarRadiation` and `TotalUser` have a weak positive correlation because:
# > - p-value is lower than the ***significance level (0.05)***, therefore ***$H_0$ is REJECTED***.
# > - The Pearson correlation coefficient (r) is low: 0.262.

# %% [markdown]
# ### Correlation between `Rainfall` and `TotalUser`:
# *****
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : `Rainfall` and `TotalUser` are not correlated.
# > * **Alternative hypothesis ($H_1$)**: `Rainfall` and `TotalUser` are correlated.
#
# **Significance level:** 0.05

# %%
sns.scatterplot(x="Rainfall(mm)", y="TotalUser", data=df);

# %%
stats.pearsonr(df['TotalUser'], df['Rainfall(mm)'])
# Out:
# PearsonRResult(statistic=-0.12248453356046968, pvalue=1.2358041104974023e-30)

# %% [markdown]
# ### Discussion:
# ****
# `Rainfall` and `TotalUser` have a weak negative correlation because:
# > - p-value is lower than the ***significance level (0.05)***, therefore ***$H_0$ is REJECTED***.
# > - The Pearson correlation coefficient (r) is low: -0.122.

# %% [markdown]
# ### Correlation between `Snowfall` and `TotalUser`:
# *****
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : `Snowfall` and `TotalUser` are not correlated.
# > * **Alternative hypothesis ($H_1$)**: `Snowfall` and `TotalUser` are correlated.
#
# **Significance level:** 0.05

# %%
sns.scatterplot(x="Snowfall(cm)", y="TotalUser", data=df);

# %%
stats.pearsonr(df['TotalUser'], df['Snowfall(cm)'])
# Out:
# PearsonRResult(statistic=-0.1414999888025562, pvalue=2.0577296078156974e-40)

# %% [markdown]
# ### Discussion:
# ****
# `Snowfall` and `TotalUser` have a weak negative correlation because:
# > - p-value is lower than the ***significance level (0.05)***, therefore ***$H_0$ is REJECTED***.
# > - The Pearson correlation coefficient (r) is low: -0.141.

# %% [markdown]
# <a id="3.2."></a>
# ### 3.2. RQ2: Is there a relationship between Temperature and Dew Point Temperature?
# ****

# %% [markdown]
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : `Temperature` and `Dewpointtemperature` are not correlated.
# > * **Alternative hypothesis ($H_1$)**: `Temperature` and `Dewpointtemperature`are correlated.
#
# **Significance level:** 0.05

# %%
sns.scatterplot(x="Temperature(°C)", y="Dewpointtemperature(°C)", data=df);

# %%
stats.pearsonr(df['Temperature(°C)'], df['Dewpointtemperature(°C)'])
# Out:
# PearsonRResult(statistic=0.9123331641748054, pvalue=0.0)

# %% [markdown]
# ### Discussion:
# ****
# `Temperature` and `Dewpointtemperature` have a strong positive correlation because:
# > - p-value is lower than the ***significance level (0.05)***, therefore ***$H_0$ is REJECTED***.
# > - The Pearson correlation coefficient (r) is high: 0.912.

# %% [markdown]
# <a id="3.3."></a>
# ### 3.3. RQ3: Which season are people most/least likely to rent an e-scooter?
# ****

# %%
meanlineprops = dict(linestyle='-.', linewidth=2.5, color='yellow')

sns.boxplot(data = df, x='Seasons', y='TotalUser', showmeans=True, meanprops = meanlineprops, meanline=True)

plt.title('Total number of e-scooter rentees between Seasons')
# Out:
# Text(0.5, 1.0, 'Total number of e-scooter rentees between Seasons')

# %% [markdown]
# ### Levene's Test for Homogeneity of Variance

# %%
stats.levene(df['TotalUser'][df['Seasons'] == 'Autumn'],
             df['TotalUser'][df['Seasons'] == 'Spring'],
             df['TotalUser'][df['Seasons'] == 'Summer'],
             df['TotalUser'][df['Seasons'] == 'Winter'],
            )
# Out:
# LeveneResult(statistic=699.2244821605859, pvalue=0.0)

# %% [markdown]
# The Levene's test on four groups of `Seasons` shows significance. The null hypothesis for the Levene's test is ***REJECTED*** since the p-value is less than the significance level (0.05) and infer that at least one pair of groups has uneven variance. Therefore, the traditional ANOVA method to compare the means of four `Seasons` groups cannot be used. A non-parametric version of ANOVA, the Welch's ANOVA will be used instead, since Welch's ANOVA does not assume homogeneity of variance between groups. The same reason for why Games-Howell post-hoc test is used in place of of Tukey HSD.

# %% [markdown]
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : The number of `TotalUser` in four seasons have the same mean.
# > * **Alternative hypothesis ($H_1$)**: The number of `TotalUser` in four seasons have different means.
#
# **Significance level:** 0.05

# %%
pg.welch_anova(dv='TotalUser', between='Seasons', data=df)
# Out:
#     Source  ddof1       ddof2            F  p-unc       np2
# 0  Seasons      3  3984.21014  1854.858057    0.0  0.211849

# %% [markdown]
# ### Discussion:
# ****
# The p-value from the Welch's ANOVA test is less than the significance level (0.05), therefore $H_0$ that says all seasons have the same mean is ***REJECTED***. However, the test did not point out which season is different from the others. The Games-Howell post-hoc test is conducted to see which season has a different mean.

# %%
pg.pairwise_gameshowell(dv='TotalUser', between='Seasons', data=df)
# Out:
#         A       B      mean(A)      mean(B)         diff         se  \
# 0  Autumn  Spring  1174.162088  1046.014040   128.148048  27.664993
# 1  Autumn  Summer  1174.162088  1481.834239  -307.672151  29.164210
# 2  Autumn  Winter  1174.162088   312.040788   862.121300  20.529086
# 3  Spring  Summer  1046.014040  1481.834239  -435.820199  28.526730
# 4  Spring  Winter  1046.014040   312.040788   733.973252  19.612919
# 5  Summer  Winter  1481.834239   312.040788  1169.793451  21.676390
#
#            T           df          pval    hedges
# 0   4.632137  4377.461281  2.209629e-05  0.139802
# 1 -10.549648  4378.403369  0.000000e+00 -0.318215
# 2  41.995113  2404.207133  0.000000e+00  1.267784
# 3 -15.277608  4366.141196  1.779132e-12 -0.459724
# 4  37.422948  2452.988681  3.774758e-15  1.121244
# 5  53.966248  2406.603982  0.000000e+00  1.616569

# %% [markdown]
# ### Discussion:
# ****
# From the Games-Howell post-hoc test, the pair-wise comparison between four groups all give p-values less than the significance level (0.05). Hence, the $H_0$ is ***REJECTED***. The number of e-scooter rentees differs in all four seasons. Summer has the highest mean of `TotalUser`, and Winter has the lowest mean of `TotalUser`. Therefore, most people would rent an e-scooter in Summer, and the least amount of people would rent an e-scooter in Winter.

# %% [markdown]
# <a id="3.4."></a>
# ### 3.4.  RQ4: Which station has the most/least e-scooter rent in a single day?
# ****

# %%
meanlineprops = dict(linestyle='-', linewidth=2.5, color='yellow')

plt.figure(figsize=(10, 5))
sns.boxplot(data = df, x='StationNumber', y='TotalUser', showmeans=True, meanprops = meanlineprops, meanline=True)

plt.title('Total number of e-scooter rentees between Stations')
# Out:
# Text(0.5, 1.0, 'Total number of e-scooter rentees between Stations')

# %% [markdown]
# ### Levene's Test for Homogeneity of Variance

# %%
stats.levene(df['TotalUser'][df['StationNumber'] == 1],
             df['TotalUser'][df['StationNumber'] == 2],
             df['TotalUser'][df['StationNumber'] == 3],
             df['TotalUser'][df['StationNumber'] == 4],
             df['TotalUser'][df['StationNumber'] == 5],
             df['TotalUser'][df['StationNumber'] == 6],
             df['TotalUser'][df['StationNumber'] == 7],
             df['TotalUser'][df['StationNumber'] == 8],
             df['TotalUser'][df['StationNumber'] == 9],
             df['TotalUser'][df['StationNumber'] == 10],
             df['TotalUser'][df['StationNumber'] == 11],
             df['TotalUser'][df['StationNumber'] == 12],
             df['TotalUser'][df['StationNumber'] == 13],
             df['TotalUser'][df['StationNumber'] == 14],
             df['TotalUser'][df['StationNumber'] == 15],
             df['TotalUser'][df['StationNumber'] == 16],
             df['TotalUser'][df['StationNumber'] == 17],
             df['TotalUser'][df['StationNumber'] == 18],
             df['TotalUser'][df['StationNumber'] == 19],
             df['TotalUser'][df['StationNumber'] == 20],
             df['TotalUser'][df['StationNumber'] == 21],
             df['TotalUser'][df['StationNumber'] == 22],
             df['TotalUser'][df['StationNumber'] == 23],
             df['TotalUser'][df['StationNumber'] == 24],
            )
# Out:
# LeveneResult(statistic=254.0804412187682, pvalue=0.0)

# %% [markdown]
# ### Discussion:
# ****
# The Levene's test for on 24 groups of `StationNumber` shows significant. Hence, the homogeneity of variance assumption for ANOVA is violated. The Welch's ANOVA method with Games-Howell post-hoc test will be used instead.

# %% [markdown]
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : The number of `TotalUser` at all stations has the same mean.
# > * **Alternative hypothesis ($H_1$)**: The number of `TotalUser` at different stations has different means.
#
# **Significance level:** 0.05

# %%
pg.welch_anova(dv='TotalUser', between='StationNumber', data=df)
# Out:
#           Source  ddof1       ddof2           F  p-unc       np2
# 0  StationNumber     23  3144.55862  343.875824    0.0  0.290298

# %% [markdown]
# ### Discussion:
# ****
# There is a mean difference of `TotalUser` between 24 stations because:
# > - The p-value is smaller than the ***significance level (0.05)***, therefore $H_0$ is ***REJECTED***.
#
# The Games-Howell post-hoc test is conducted too observe the mean difference between pairs of stations:

# %%
post_hoc = pg.pairwise_gameshowell(dv='TotalUser', between='StationNumber', data=df)
post_hoc
# Out:
#       A   B      mean(A)      mean(B)        diff         se          T  \
# 0     1   2   772.780392   607.760789  165.019603  35.023293   4.711710
# 1     1   3   772.780392   427.545645  345.234747  31.806366  10.854266
# 2     1   4   772.780392   286.924196  485.856197  29.611127  16.407893
# 3     1   5   772.780392   185.375139  587.405253  28.425046  20.665059
# 4     1   6   772.780392   195.062918  577.717474  28.523844  20.253843
# ..   ..  ..          ...          ...         ...        ...        ...
# 271  21  23  1535.310835  1316.807743  218.503091  77.998775   2.801366
# 272  21  24  1535.310835   956.590393  578.720442  70.087838   8.257074
# 273  22  23  1477.202369  1316.807743  160.394626  75.481552   2.124951
# 274  22  24  1477.202369   956.590393  520.611976  67.275262   7.738535
# 275  23  24  1316.807743   956.590393  360.217350  61.265197   5.879641
#
#              df          pval    hedges
# 0    687.614688  7.421157e-04  0.348417
# 1    579.432671  1.243450e-13  0.802641
# 2    471.310498  1.776357e-14  1.213315
# 3    407.821002  1.285638e-13  1.528120
# 4    413.130845  6.716849e-14  1.497712
# ..          ...           ...       ...
# 271  702.509488  4.378205e-01  0.207153
# 272  594.260075  2.371436e-13  0.610586
# 273  714.857019  9.032775e-01  0.157134
# 274  614.606957  1.148903e-11  0.572242
# 275  663.376272  1.772030e-06  0.434782
#
# [276 rows x 10 columns]

# %%
max_a = post_hoc['mean(A)'].max() # Find station with highest mean in column A
max_b = post_hoc['mean(B)'].max() # Find station with highest mean in column B
post_hoc[post_hoc['mean(A)'] == max_a]
# Out:
#       A   B      mean(A)      mean(B)         diff          se          T  \
# 261  19  20  2155.788932  1713.819022   441.969910  101.536396   4.352823
# 262  19  21  2155.788932  1535.310835   620.478097   98.517699   6.298138
# 263  19  22  2155.788932  1477.202369   678.586563   96.537002   7.029290
# 264  19  23  2155.788932  1316.807743   838.981189   92.449210   9.075050
# 265  19  24  2155.788932   956.590393  1199.198539   85.879873  13.963674
#
#              df          pval    hedges
# 261  705.071656  3.594587e-03  0.321878
# 262  683.953149  1.477539e-07  0.465729
# 263  665.762989  1.420048e-09  0.519795
# 264  617.166898  1.709743e-13  0.671073
# 265  511.809742  9.381385e-14  1.032572

# %%
post_hoc[post_hoc['mean(B)'] == max_b]
# Out:
#       A   B      mean(A)      mean(B)         diff         se          T  \
# 17    1  19   772.780392  2155.788932 -1383.008540  82.742634 -16.714582
# 39    2  19   607.760789  2155.788932 -1548.028143  80.926337 -19.128855
# 60    3  19   427.545645  2155.788932 -1728.243287  79.586971 -21.715153
# 80    4  19   286.924196  2155.788932 -1868.864736  78.735379 -23.736023
# 99    5  19   185.375139  2155.788932 -1970.413793  78.297026 -25.165883
# 117   6  19   195.062918  2155.788932 -1960.726014  78.332948 -25.030668
# 134   7  19   407.941231  2155.788932 -1747.847701  79.784339 -21.907153
# 150   8  19   867.243455  2155.788932 -1288.545477  86.157713 -14.955660
# 165   9  19  1458.793962  2155.788932  -696.994970  97.067790  -7.180497
# 179  10  19   922.247838  2155.788932 -1233.541094  83.602130 -14.754900
# 192  11  19   750.043349  2155.788932 -1405.745582  81.692286 -17.207813
# 204  12  19   855.438433  2155.788932 -1300.350499  82.609813 -15.740872
# 215  13  19   998.705878  2155.788932 -1157.083054  84.543005 -13.686325
# 225  14  19  1051.481814  2155.788932 -1104.307118  85.474819 -12.919678
# 234  15  19  1083.948455  2155.788932 -1071.840477  86.301210 -12.419762
# 242  16  19  1180.375499  2155.788932  -975.413433  88.119012 -11.069273
# 249  17  19  1328.181609  2155.788932  -827.607323  90.865091  -9.108089
# 255  18  19  1628.649563  2155.788932  -527.139369  96.249854  -5.476781
#
#              df          pval    hedges
# 17   453.760092  2.290390e-13 -1.235994
# 39   419.276714  0.000000e+00 -1.414522
# 60   393.825727  2.087219e-14 -1.605771
# 80   377.739062  3.745892e-13 -1.755208
# 99   369.507438  7.649437e-14 -1.860942
# 117  370.180513  9.625634e-14 -1.850944
# 134  397.567856  1.215694e-13 -1.619969
# 150  516.786110  0.000000e+00 -1.105927
# 165  670.982213  5.100794e-10 -0.530976
# 179  469.931276  3.349543e-13 -1.091081
# 192  433.847393  3.019807e-14 -1.272467
# 204  451.249417  9.436896e-14 -1.163991
# 215  487.435069  0.000000e+00 -1.012063
# 225  504.496141  0.000000e+00 -0.955372
# 234  519.342734  2.441380e-13 -0.918405
# 242  550.827254  2.484679e-13 -0.818540
# 249  594.512297  1.121325e-13 -0.673516
# 255  662.833866  1.648669e-05 -0.404992

# %% [markdown]
# ### Station with highest `TotalUser`:
# Station 19 has the highest mean of total e-scooter rentees (mean = 2160). The pair-wise comparison (Games-Howell post-hoc test) shows that Station 19's mean of `TotalUser` if different from all other stations (p-value < 0.05). Hence, it can be concluded that Station 19 has the most e-scooter rentees.

# %%
min_a = post_hoc['mean(A)'].min() # Find station with lowest mean in column A
min_b = post_hoc['mean(B)'].min() # Find station with lowest mean in column B
post_hoc[post_hoc['mean(A)'] == min_a]
# Out:
#      A   B     mean(A)      mean(B)         diff         se          T  \
# 86   5   6  185.375139   195.062918    -9.687779   9.883852  -0.980162
# 87   5   7  185.375139   407.941231  -222.566092  18.088132 -12.304537
# 88   5   8  185.375139   867.243455  -681.868316  37.212784 -18.323496
# 89   5   9  185.375139  1458.793962 -1273.418823  58.170401 -21.891182
# 90   5  10  185.375139   922.247838  -736.872699  30.837572 -23.895289
# 91   5  11  185.375139   750.043349  -564.668211  25.204549 -22.403424
# 92   5  12  185.375139   855.438433  -670.063294  28.036066 -23.900047
# 93   5  13  185.375139   998.705878  -813.330739  33.304045 -24.421380
# 94   5  14  185.375139  1051.481814  -866.106675  35.603152 -24.326685
# 95   5  15  185.375139  1083.948455  -898.573316  37.543822 -23.933986
# 96   5  16  185.375139  1180.375499  -995.000360  41.552377 -23.945691
# 97   5  17  185.375139  1328.181609 -1142.806470  47.096757 -24.265078
# 98   5  18  185.375139  1628.649563 -1443.274424  56.795018 -25.411990
# 99   5  19  185.375139  2155.788932 -1970.413793  78.297026 -25.165883
# 100  5  20  185.375139  1713.819022 -1528.443883  65.355027 -23.386784
# 101  5  21  185.375139  1535.310835 -1349.935696  60.558871 -22.291296
# 102  5  22  185.375139  1477.202369 -1291.827230  57.280299 -22.552732
# 103  5  23  185.375139  1316.807743 -1131.432604  50.084889 -22.590299
# 104  5  24  185.375139   956.590393  -771.215254  36.564906 -21.091679
#
#              df          pval    hedges
# 86   725.593113  9.999990e-01 -0.072480
# 87   480.082586  0.000000e+00 -0.909884
# 88   389.002073  8.393286e-14 -1.354968
# 89   374.038146  1.295630e-13 -1.618788
# 90   400.936634  1.936229e-13 -1.766986
# 91   420.527404  3.017586e-13 -1.656667
# 92   409.111690  1.629807e-13 -1.767338
# 93   395.462477  3.974598e-14 -1.805889
# 94   391.394494  1.317835e-13 -1.798886
# 95   388.549336  2.160494e-13 -1.769847
# 96   383.925529  1.465494e-13 -1.770713
# 97   379.421348  6.161738e-14 -1.794331
# 98   374.537132  9.914292e-14 -1.879141
# 99   369.507438  7.649437e-14 -1.860942
# 100  371.930270  0.000000e+00 -1.729383
# 101  373.252341  2.756684e-13 -1.648375
# 102  374.356890  0.000000e+00 -1.667708
# 103  377.604106  1.341149e-13 -1.670486
# 104  389.925489  4.696243e-14 -1.559667

# %%
post_hoc[post_hoc['mean(B)'] == min_b]
# Out:
#     A  B     mean(A)     mean(B)        diff         se          T  \
# 3   1  5  772.780392  185.375139  587.405253  28.425046  20.665059
# 25  2  5  607.760789  185.375139  422.385650  22.598935  18.690511
# 46  3  5  427.545645  185.375139  242.170506  17.196680  14.082399
# 66  4  5  286.924196  185.375139  101.549057  12.684624   8.005681
#
#             df          pval    hedges
# 3   407.821002  1.285638e-13  1.528120
# 25  435.416206  5.917489e-14  1.382108
# 46  493.798347  0.000000e+00  1.041352
# 66  615.370449  1.944667e-12  0.591996

# %% [markdown]
# ### Stations with lowest `TotalUser`:
# Station 5 has the lowest mean of `TotalUser` (mean = 185). The pair-wise comparison (Games-Howell post-hoc test) shows that Station 5's mean of `TotalUser` is different from other stations (p-value < 0.05), except Station 6 (p-value = 0.99). Hence, it can be concluded that Station 5 and Station 6 has the lowest number of e-scooter rentees.

# %% [markdown]
# <a id="3.5."></a>
# ### 3.5.  RQ5: Does `Seasons` affect e-scooter stations' closure?
# ****

# %%
chi2table = pd.crosstab(df['Seasons'], df['OperationDay'])
chi2table
# Out:
# OperationDay   No   Yes
# Seasons
# Autumn        247  1937
# Spring         48  2160
# Summer          0  2208
# Winter          0  2160

# %% [markdown]
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : `OperationDay` is independent of `Seasons`.
# > * **Alternative hypothesis ($H_1$)**: `OperationDay` is dependent on `Seasons`.
#
# **Significance level:** 0.05

# %%
result = stats.chi2_contingency(chi2table)

print('statistic: ', result[0])
print('p-value: ', result[1])
print('dof: ', result[2])
print('Expected frequency:\n', result[3])
# Out:
# statistic:  585.2066161470536
# p-value:  1.62305344566663e-126
# dof:  3
# Expected frequency:
#  [[  73.54794521 2110.45205479]
#  [  74.35616438 2133.64383562]
#  [  74.35616438 2133.64383562]
#  [  72.73972603 2087.26027397]]

# %% [markdown]
# ### Discussion:
# `Seasons` does affect whether a station is open or not because:
# > - p-value is lower than the ***significance level (0.05)***, therefore ***$H_0$ is REJECTED***. Most of the time the stations were closed during Autumn.
#
# The stations were most likely closed in Autumn than any other seasons.

# %% [markdown]
# <a id="3.6."></a>
# ### 3.6.  RQ6: Are people more likely to rent an e-scooter when the temperature is above 20°C?
# ****

# %%
meanlineprops = dict(linestyle='-', linewidth=2.5, color='yellow')

sns.boxplot(data = df, x='Below20', y='TotalUser', showmeans=True, meanprops = meanlineprops, meanline=True)

plt.title('Total number of e-scooter rentees between above 20°C days vs. below 20°C days')
# Out:
# Text(0.5, 1.0, 'Total number of e-scooter rentees between above 20°C days vs. below 20°C days')

# %% [markdown]
# ### Levene's Test for Homogeneity of Variance

# %%
stats.levene(df['TotalUser'][df['Below20'] == 'Yes'], 
             df['TotalUser'][df['Below20'] == 'No'], )
# Out:
# LeveneResult(statistic=556.0486208767684, pvalue=2.990213237060444e-119)

# %% [markdown]
# ### Discussion:
# ****
# The p-value of the Levene's test is less than the significance level of 0.05, which means the variance between two testing groups are not equal. Hence, the Welch's t-test is conducted because it does not assume homogeneity of variance. This t-test is also one-tailed to compare if one condition has higher mean than the other.

# %% [markdown]
# **Hypotheses:**
# > * **Null hypothesis ($H_0$)** : The mean of `TotalUser` when the temperature is below 20°C is NOT less than the mean of `TotalUser` when the temperature is above 20°C.
# > * **Alternative hypothesis ($H_1$)**: The mean of `TotalUser` when the temperature is below 20°C is less than the mean of `TotalUser` when the temperature is above 20°C.
#
# **Significance level:** 0.05

# %%
stats.ttest_ind(df['TotalUser'][df['Below20'] == 'Yes'], 
                df['TotalUser'][df['Below20'] == 'No'],
                equal_var=False,
                alternative='less')
# Out:
# Ttest_indResult(statistic=-42.06014404217549, pvalue=0.0)

# %% [markdown]
# ### Discussion:
# People tend to rent an e-scooter when the temperature is above 0°C because:
# > - p-value is lower than the ***significance level (0.05)***, therefore ***$H_0$ is REJECTED***. The mean of `TotalUser` when the temperature is below 20°C is less than the mean of `TotalUser` when the temperature is above 20°C.

# %% [markdown]
# <a id="3.7."></a>
# ### 3.7.  RQ7: Are people more likely to rent an e-scooter on completely dry days (no rain, no snow)?
# ****

# %%
meanlineprops = dict(linestyle='-', linewidth=2.5, color='yellow') # Mean line properties

sns.boxplot(data = df, 
            x='CompletelyDry', 
            y='TotalUser', 
            showmeans=True, 
            meanprops = meanlineprops, 
            meanline=True)

plt.title('Total number of e-scooter rentees between completely dry days vs. rainy/snowy days')
# Out:
# Text(0.5, 1.0, 'Total number of e-scooter rentees between completely dry days vs. rainy/snowy days')

# %% [markdown]
# From the scatterplots in RQ1, 2, and 3, it looks like the number of e-scooter rentees decreases as `Rainfall` or `Snowfall` increases, and the amount of rentees seems extremely high there is no rain or snow. However, the correlation is not linear, therefore the Pearson correlation tests show very weak correlation between `Rainfall` or `Snowfall` and the number of users. Hence, this time, an independent t-test is carried out to see if people are more likely to rent an e-scooter on completely no rain and no snow days.

# %% [markdown]
# ### Levene's Test for Homogeneity of Variance

# %%
stats.levene(df['TotalUser'][df['CompletelyDry'] == 'Yes'],
             df['TotalUser'][df['CompletelyDry'] == 'No']
            )
# Out:
# LeveneResult(statistic=722.8106155341762, pvalue=4.7201285164048664e-153)

# %% [markdown]
# The p-value from the Levene's test is less than the significance level (0.05), hence the test yields significance, which means that the two samples do not have equal variance.
# Hence, the independent t-test must not assume equal variance between groups, and the Welch's one-tailed t-test is conducted.
#
# ***Hypotheses:***
# > * **Null hypothesis ($H_0$)** : The mean of `TotalUser` on dry (no rain, no snow) days is NOT less than the mean of `TotalUser` on days with rain or snow.
# > * **Alternative hypothesis ($H_1$)**:  The mean of `TotalUser` on dry (no rain, no snow) days is less than the mean of `TotalUser` on days with rain or snow.
#
# **Significance level:** 0.05

# %%
stats.ttest_ind(df['TotalUser'][df['CompletelyDry'] == 'Yes'], 
                df['TotalUser'][df['CompletelyDry'] == 'No'],
                equal_var=False,
                alternative='less')
# Out:
# Ttest_indResult(statistic=56.96953405355597, pvalue=1.0)

# %% [markdown]
# ### Discussion:
# ****
# The mean of `TotalUser` who rented e-scooter is higher when there is no rain and snow on a given day because:
# > - p-value is higher than the ***significance level (0.05)***, therefore ***$H_0$ is NOT rejected***. People tends to rent more e-scooters on dry days without rain and snow.

# %% [markdown]
# <a id="3.8."></a>
# ### 3.8.  RQ8: Has the percentage of registered/newly registered user increase after 6 months (from Dec 2017 to Jun 2018)?
# ****

# %%
test_groups = df[(df['IsDec2017'] == 'Yes') | (df['IsJun2018'] == 'Yes')] # Extract relevant entries

meanlineprops = dict(linestyle='-', linewidth=2.5, color='yellow') # Mean line properties
fig, axes = plt.subplots(1, 2, figsize=(14, 10))  # Subplot 1x2

sns.boxplot(data = test_groups, 
            x='IsDec2017', 
            y='RegisteredPercent', 
            showmeans=True, 
            meanprops = meanlineprops, 
            meanline=True, 
            ax=axes[0])

sns.boxplot(data=test_groups, 
            x='IsDec2017', 
            y='NewRegisteredPercent', 
            showmeans=True, 
            meanprops = meanlineprops, 
            meanline=True, 
            ax=axes[1])

axes[0].set_title('Registered Users Percentage between December 2017 vs. June 2018')
axes[1].set_title('Newly Registered Users Percentage between December 2017 vs. June 2018')
# Out:
# Text(0.5, 1.0, 'Newly Registered Users Percentage between December 2017 vs. June 2018')

# %% [markdown]
# ### Registered Users:

# %% [markdown]
# ### Levene's Test for Homogeneity of Variance

# %%
stats.levene(df['RegisteredPercent'][df['IsDec2017'] == 'Yes'], 
             df['RegisteredPercent'][df['IsJun2018'] == 'Yes'])
# Out:
# LeveneResult(statistic=111.19758865822556, pvalue=4.157929150125364e-25)

# %% [markdown]
# The p-value of the Levene's test is less than the significance level of 0.05, which means the two groups do not have equal variances. Therefore, the Welch's one-tailed t-test is conducted to test if the mean of registered user percentage in December 2017 is higher than the mean of registered user percentage in June 2018.
#
# ***Hypotheses:***
# > * **Null hypothesis ($H_0$)** : The mean of `RegisteredPercent` in December 2017 days is NOT less than the mean of `RegisteredPercent` in June 2018.
# > * **Alternative hypothesis ($H_1$)**:  The mean of `RegisteredPercent` in December 2017 days is less than the mean of `RegisteredPercent` in June 2018.
#
# **Significance level:** 0.05

# %%
stats.ttest_ind(df['RegisteredPercent'][df['IsDec2017'] == 'Yes'], 
                df['RegisteredPercent'][df['IsJun2018'] == 'Yes'],
                equal_var=False,
                alternative='less')
# Out:
# Ttest_indResult(statistic=22.225013712608714, pvalue=1.0)

# %% [markdown]
# ### Newly Registered Users:

# %% [markdown]
# ### Levene's Test for Homogeneity of Variance

# %%
stats.levene(df['NewRegisteredPercent'][df['IsDec2017'] == 'Yes'], 
             df['NewRegisteredPercent'][df['IsJun2018'] == 'Yes'])
# Out:
# LeveneResult(statistic=68.84000147623395, pvalue=2.3971427403326277e-16)

# %% [markdown]
# The p-value of the Levene's test is less than the significance level of 0.05, which means the two groups do not have equal variances. Therefore, the Welch's one-tailed t-test is conducted to test if the mean of newly registered user percentage in December 2017 is higher than the mean of newly registered user percentage in June 2018.
#
# ***Hypotheses:***
# > * **Null hypothesis ($H_0$)** : The mean of `NewRegisteredPercent` in December 2017 days is NOT less than the mean of `NewRegisteredPercent` in June 2018.
# > * **Alternative hypothesis ($H_1$)**:  The mean of `NewRegisteredPercent` in December 2017 days is less than the mean of `NewRegisteredPercent` in June 2018.
#
# **Significance level:** 0.05

# %%
stats.ttest_ind(df['NewRegisteredPercent'][df['IsDec2017'] == 'Yes'], 
                df['NewRegisteredPercent'][df['IsJun2018'] == 'Yes'],
                equal_var=False,
                alternative='less')
# Out:
# Ttest_indResult(statistic=3.3196737174476407, pvalue=0.999528955415348)

# %% [markdown]
# ### Discussion:
# ****
# The mean of both `RegisteredPercent` and `NewRegisteredPercent` in December 2017 were both higher than that of June 2018 because:
# > - p-value is higher than the ***significance level (0.05)***, therefore ***$H_0$ is NOT rejected***. The percentage of registered users and newly registered users had dropped over the course of 6 months (Dec 2017 - Jun 2018).

# %% [markdown]
# <a id="3.9."></a>
# ### 3.9.  RQ9: Are stations attracting unregistered users to register?
# ****

# %%
test_groups = df[['CasualPercent', 'NewRegisteredPercent']] # Extract 2 relevant fields

meanlineprops = dict(linestyle='-', linewidth=2.5, color='yellow') # Properties of the mean line

sns.boxplot(data=test_groups.melt(), 
            x='variable', 
            y='value', 
            showmeans=True, 
            meanprops = meanlineprops, 
            meanline=True,);

plt.title('Percentage of Casual Users vs. Newly Registered Users');

# %% [markdown]
# ### Levene's Test for Homogeneity of Variance

# %%
stats.levene(df['CasualPercent'], 
             df['NewRegisteredPercent'])
# Out:
# LeveneResult(statistic=1083.6859962444853, pvalue=1.1731934052907037e-230)

# %% [markdown]
# The p-value of the Levene's test is less than the significance level of 0.05, which means the two groups do not have equal variances. Therefore, the Welch's one-tailed t-test is conducted to test if the mean of `CasualUser` is higher than the mean of `Newregistereduser`.
#
# ***Hypotheses:***
# > * **Null hypothesis ($H_0$)** : The mean of `CasualPercent` is NOT less than the mean of `NewRegisteredPercent`.
# > * **Alternative hypothesis ($H_1$)**:  The mean of `CasualPercent` is less than the mean of `NewRegisteredPercent`.
#
# **Significance level:** 0.05

# %%
stats.ttest_ind(df['CasualPercent'], 
                df['NewRegisteredPercent'],
                equal_var=False,
                alternative='less')
# Out:
# Ttest_indResult(statistic=183.8416416917115, pvalue=1.0)

# %% [markdown]
# ### Discussion:
# ****
# The mean of `CasualPercent` higher than the mean of `NewRegisteredPercent` because:
# > - p-value is higher than the ***significance level (0.05)***, therefore ***$H_0$ is NOT rejected***. Unregistered users were not keen on registering to e-scooter stations.

# %% [markdown]
# <a id="4"></a>
# <h1 style="color:#00008B;font-size:40px;font-family:Georgia;text-align:center;"><strong>IV. References</strong></h1>
#
# *****

# %% [markdown]
# <a id="Ref1"></a>
# [1] Arizona State University. "World: Highest Temperature." https://wmo.asu.edu/content/world-highest-temperature (accessed January 7, 2023)
